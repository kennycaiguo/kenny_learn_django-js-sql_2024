# %% [markdown]
# # Python String

# %% [markdown]
# ### 1.String Formatting

# %%
# 1.% operator
# print("%s %s" %("hello","world"))
# test:
# print("Hello %s,welcome to my %s"%("everyone","Live show"))

# 2."{}".format or "{var}".format(var=value)
# print("{} is my favorite food".format("Ox tail"))
# print("{name},how are you?".format(name="Jackline"))
# test2:
# print("I love {} and {}".format("money","gold"))
# print("I love {var}".format(var="pretty girls"))

# 3.the fstring
# name="Jade"
# gender="female"
# print(f"{name} is a {gender}")
# test3:
# obj = {"name":"Jack","age":18}    

# print(f"This guy named {obj['name']},and he is {obj['age']} years old")
# Out:
# This guy named Jack,and he is 18 years old

# %% [markdown]
# ## 2.String Methods

# %%
# capitalize()  make only the First letter Upper case of the sentence
# txt = "welcome to my live show,everyone!!"
# print(txt.capitalize())
# Out:
# Welcome to my live show,everyone!!

# %%
# casefold() turn every letter in a string into lower case
# s="Hello World"
# print(s.casefold())
# Out:
# hello world

# %%
# center() Returns a centered string,string.center(length, character),default character is space
# s = "welcome"
# print(s.center(20,"*"))
# Out:
# ******welcome*******

# %%
# count(value,start,end) Returns the number of times a specified value occurs in a string,it takes at least 1 parameter
# s="hello mike,hello lucy,hello everyone"
# print(s.count("hello"))
# Out:
# 3

# %%
# endswith()   Returns true if the string ends with the specified value
# txt = "Hello ,python"
# print(txt.endswith('on'))
# Out:
# True

# %%
# expandtabs(num) Sets the tab size of the string,expandtabs(number) set the space width by number of \t in the string
# info = "H\te\tl\tl\to"
# print(info.expandtabs(5))
# Out:
# H    e    l    l    o

# %%
# find()       Searches the string for a specified value and returns the position of where it was found
# s="hello mike,hello lucy,hello everyone"
# print(s.find("hello"))
# print(s.find("hello"))
# Out:
# 0
# 0

# %%
# format()     Formats specified values in a string
# print("I love to eat {}".format("fish"))
# Out:
# I love to eat fish

# %%
# format_map()  Formats specified values in a string
# dic = {"name":"Joan","gender":"Female"}
# print("{name} is a {gender}".format_map(dic))
# test:
# dic = {"name":"Joan","age":20}
# print("{name} is {age} years old".format_map(dic))
# Out:
# Joan is 20 years old

# %%
# index() Searches the string for a specified value and returns the position of where it was found
# print("ice cream is my favorite food".index("favorite"))
# Out:
# 16

# %%
# isalnum() Returns True if all characters in the string are alphanumeric
# ns = "12345"
# print(ns.isalnum()) # True

# %%
# isalpha() Returns True if all characters in the string are in the alphabet
# s = "welcome"
# print(s.isalpha())
# Out:
# False

# %%
# isascii() Returns True if all characters in the string are ascii characters
txt = "this"
print(txt.isascii())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c805ce4a6237> in <module>
#       1 # isascii() Returns True if all characters in the string are ascii characters
#       2 txt = "this"
# ----> 3 print(txt.isascii())
#
# AttributeError: 'str' object has no attribute 'isascii'

# %%
# isdecimal() Returns True if all characters in the string are decimals
# s="54321"
# print(s.isdecimal()) # True
# Out:
# True

# %%
# isdigit() Returns True if all characters in the string are digits
# s="5432"
# print(s.isdigit())  # True
# Out:
# True

# %%
# isidentifier() Returns True if the string is an identifier 
# s = "i am a string"  # False ?
# s = "string"  # True
# print(s.isidentifier())
# Out:
# True

# %%
# islower() Returns True if all characters in the string are lower case
# s = "hello"
# print(s.islower())
# Out:
# False

# %%
# isnumeric() Returns True if all characters in the string are numeric
ns = "6798"
print(ns.isnumeric())
# Out:
# True

# %%
# isprintable() Returns True if all characters in the string are printable
# obj= '{"name":"boss"}'
# print(obj.isprintable())
# Out:
# True

# %%
# isspace() Returns True if all characters in the string are whitespaces
# s=" "
# print(s.isspace())
# Out:
# True

# %%
# istitle() Returns True if the string follows the rules of a title
# title = "This Is A Title"
# print(title.istitle())
# Out:
# True

# %%
# isupper() Returns True if all characters in the string are upper case
# us = "HELLO, FRIENDS"
# print(us.isupper())
# Out:
# True

# %%
# join()    Converts the elements of an iterable into a string
# sl =["hello","welcome","to","my show"]
# print("-".join(sl))
# Out:
# hello-welcome-to-my show

# %%
# ljust(width, fillchar)   Returns a left justified version of the string
# s="hello"
# print(s.ljust(20,"@"))
# Out:
# hello@@@@@@@@@@@@@@@

# %%
# lower() Converts a string into lower case
# s = "Can You Help Me?"
# print(s.lower())
# Out:
# can you help me?

# %%
# lstrip() Returns a left trim version of the string
# s="     hello    "
# print(s.lstrip())
# Out:
# hello

# %%
# maketrans() Returns a translation table to be used in translations
# txt = "Hello Sam!"

# mytable = str.maketrans("S", "P") # P will replace S

# print(txt.translate(mytable))
# test:
# s="I got an A"
# ret = s.maketrans("A","B")
# print(s.translate(ret))
# Out:
# I got an B

# %%
# partition(value) Returns a tuple where the string is parted into three parts: sub string before value,value,sub string after value
# s="let us have some good quality time together"
# print(s.partition("good"))
# Out:
# ('let us have some ', 'good', ' quality time together')

# %%
# replace(oldVal,newVal) Returns a string where oldVal is replaced with newVal
# s = "I love cheese cake"
# print(s.replace("cheese","butter"))
# Out:
# I love butter cake

# %%
# rfind() Searches the string for a specified value and returns the last position of where it was found
# s="Hello boys,Hello girls,Hello everyone"
# print(s.rfind("Hello"))
# Out:
# 23

# %%
# rindex() Searches the string for a specified value and returns the last position of where it was found
# s="Hello boys,Hello girls,Hello everyone"
# print(s.rindex("Hello"))
# Out:
# 23

# %%
# rjust(num) Returns a right justified version of the string with the length of num
# s="hello"
# print(s.rjust(15,"#"))
# Out:
# ##########hello

# %%
# rpartition() Returns a tuple where the string is parted into three parts
# Example
# Search for the last occurrence of the word "bananas", and return a tuple with three elements:

# 1 - everything before the "match"
# 2 - the "match"
# 3 - everything after the "match"

txt = "I could eat bananas all day, bananas are my favorite fruit"

x = txt.rpartition("bananas")
# x = txt.partition("bananas")
print(x)
# Out:
# ('I could eat ', 'bananas', ' all day, bananas are my favorite fruit')

# %%
# rsplit() Splits the string at the specified separator, and returns a list
# Out:
# Hello Pam!

# %%
# rstrip() Returns a right trim version of the string
# s="   hello   "
# s2="world"
# # print(s+s2)
# print(s.rstrip()+s2)
# Out:
#    helloworld

# %%
# split() Splits the string at the specified separator, and returns a list
# txt = "I could eat bananas all day, bananas are my favorite fruit"
# print(txt.split("bananas"))
# Out:
# ['I could eat ', ' all day, ', ' are my favorite fruit']

# %%
# splitlines() Splits the string at line breaks and returns a list
# s="welcome to my\n live show"
# print(s.splitlines())
# txt = "I could eat bananas\n all day, bananas\n are my favorite fruit"
# print(txt.splitlines())
# Out:
# ['I could eat bananas', ' all day, bananas', ' are my favorite fruit']

# %%
# startswith() Returns true if the string starts with the specified value
# s="Learining python is so much fun"
# print(s.startswith('Le'))
# Out:
# True

# %%
# strip() Returns a trimmed version of the string
# s="   hello   "
# s2="world"
# # print(s+s2)
# print(s.strip()+s2)
# Out:
# helloworld

# %%
# swapcase() Swaps cases, lower case becomes upper case and vice versa
# s="Hello"
# print(s.swapcase())
# Out:
# hELLO

# %%
# title() Converts the first character of each word to upper case
# s="let's learn python"
# print(s.title())
# Out:
# Let'S Learn Python

# %%
# translate() Returns a translated string

# %%
# upper() Converts a string into upper case
s="hello"
print(s.upper())
# Out:
# HELLO

# %%
# zfill() Fills the string with a specified number of 0 values at the beginning
s="100" 
print(s.zfill(5)) # only works with the number charactor
# Out:
# 00100
